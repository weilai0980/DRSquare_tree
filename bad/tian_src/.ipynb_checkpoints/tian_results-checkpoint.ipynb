# %%
# %matplotlib inline

import os 
import sys 
import time
import hashlib

from datetime  import datetime 

import numpy as np  # learn 
import pandas as pd # learn
from pandas import *
from numpy import *

from scipy import stats # look at scipy
from scipy import linalg
from scipy import *

 
import matplotlib as mplt # learn matplolib 
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d

import seaborn as sns 
sns.set_style("whitegrid")
sns.set(rc={"figure.figsize": (14, 6)})

import IPython
from IPython.display import display


import matplotlib
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
 
import sklearn as sk
import itertools


from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.sql.types import *

from pyspark.mllib.regression import LabeledPoint
import random
import time
import copy

# %%
# results plot
import matplotlib.pyplot as plt

# matplotlib.rcParams.update({'font.size': 52})

matplotlib.rcParams.update({'font.size': 72})

maxdepth=7
x=range(0,maxdepth+1)

fig = plt.figure()
plt.legend( loc=1)


# legend(framealpha=0.5)

plt.tick_params(labelsize= maxdepth)

capp_test_error=[1074838.02257, 1074437.8287446771, 1074565.7027683556, 1075109.9780677597, 1074537.4393239901, 1074242.333610338, 1073387.8549230846, 1072270.5637668928]

bin_test_error=[1074838.02257,1074453.77671, 1074614.6165, 1075137.30007, 1074488.31044 ,1074212.84323 ,1073403.56541,1072303.28081] 

width_test_error=[1074838.02257,1074254.6896224376, 1074067.0930413587, 1074458.0096581331, 1075208.6106615602, 1074740.0711625235, 1073564.912210552,1072414]

mllib_test_error=[1062693.64813, 983349.243325, 983391.372498 ,983390.447478 ,983410.746998 ,983287.677277,983218.90788,983229.280591] 

exact_test_error=[1074838.02257,1073316.7418499133, 1074081.2873873087, 1073351.9665948125, 1073322.5980285993, 1073292.0676254511, 1073062.3896627428, 1072596.0525539306]

plt.title('Test error on data with outliers', fontsize = 25)


p1=plt.plot(x, capp_test_error,'r--^', label='c_approx')
p2=plt.plot(x, bin_test_error,'b-H',label='binNum_fixed')
p3=plt.plot(x, width_test_error,'g-<',label='width_fixed')
p4=plt.plot(x, exact_test_error,'c-8',label='exact_fixed')
# p5=plt.plot(x, mllib_test_error,'k-D',label='MLlib_fixed')

# p1=plt.plot(x, test_error,'r--^' )
# p2=plt.plot(x, bin_test_error,'b-H')
# p3=plt.plot(x, bin_test_error,'g-<')
# p4=plt.plot(x, bin_test_error,'c-8')
# p5=plt.plot(x, bin_test_error,'k-D')

# plt.figlegend((p1, p2,p3,p4,p5), ('c_approx', 'binNum_fixed','width_fixed','exact_fixed','MLlib_fixed'), \
#            bbox_to_anchor=[0.5, 0.5], 
#            'upper right')

# axes = plt.gca()
# axes.set_xlim([xmin,xmax])
# axes.set_ylim([ymin,ymax])

plt.legend( loc=1,ncol=2)

plt.xlabel('Max depth',fontsize=18)
plt.ylabel('Mean square error',fontsize=18)

plt.xticks( fontsize = 15)
plt.yticks( fontsize = 15)
# plt.axis([1,maxdepth,980000,1080000],fontsize=48)

# plt.axis([0,maxdepth+1,0,0])
plt.axis(fontsize=98)


plt.legend( loc='upper right',fontsize=21 )

plt.savefig('/home/tguo/test.png')

# %%
# results plot
import matplotlib.pyplot as plt

# matplotlib.rcParams.update({'font.size': 52})

matplotlib.rcParams.update({'font.size': 72})

maxdepth=8
x=range(0,maxdepth)

fig = plt.figure()


# legend(framealpha=0.5)

plt.tick_params(labelsize= maxdepth)

capp_train_error=[1028782.76693,1028415.244310336, 1028540.0697712521, 1028884.5523299589, 1028339.3640963054, 1027913.7543517951, 1027202.2369429773, 1026151.4573390299]

bin_train_error=[1028782.76693,1028431.67887,1028587.67404 ,1028913.94437,1028295.12782,1027878.85149,1027236.53432,1026196.87638 ]

width_train_error=[1028782.76693,1028209.3634036074, 1027952.9048790738, 1028306.1027991395, 1028878.2982615286, 1028532.4716018183, 1027652.3219463517,1026652]

mllib_train_error=[1017655.01623,991399.134686,991346.758955,991255.563213,991192.600536,991027.759265,990908.760448,990779.857888]

exaxt_train_error = [1028782.76693, 1027399.5875134228, 1027961.7455679877, 1027355.9410964268, 1027379.4504403136, 1027449.3567722733, 1027225.3963077085, 1026345.1323377528]

plt.title('Training error on data with outliers', fontsize = 25)

p1=plt.plot(x, capp_train_error,'r--^', label='c_approx')
p2=plt.plot(x, bin_train_error,'b-H',label='binNum_fixed')
p3=plt.plot(x, width_train_error,'g-<',label='width_fixed')
p4=plt.plot(x, exaxt_train_error,'c-8',label='exact_fixed')
# p5=plt.plot(x, mllib_train_error,'k-D',label='MLlib_fixed')

plt.xlabel('Max depth',fontsize=18)
plt.ylabel('Mean square error',fontsize=18)

plt.xticks( fontsize = 15)
plt.yticks( fontsize = 15)
# plt.axis([0,maxdepth,1000000,1080000],fontsize=48)

plt.axis(fontsize=98)

plt.legend( loc='lower left',fontsize=21 )

plt.savefig('/home/tguo/train.png')

# %%
# results plot
import matplotlib.pyplot as plt

# matplotlib.rcParams.update({'font.size': 52})

matplotlib.rcParams.update({'font.size': 72})

maxdepth=8
x=range(0,maxdepth)

fig = plt.figure()

plt.tick_params(labelsize= maxdepth)

capp_test=[769.741145127,761.9518481781977, 738.2785659728175, 702.9620327293563, 651.5325922367125, 486.69008451630873, 183.40408148431095, 532.4031993554111]
bin_test=[769.741145127,764.324273897,739.985248741,703.871007467,649.6643822,494.899825276,178.974866547,524.008347606] 
width_test= [769.741145127,737,740,731,717,660,413, 385]
mllib_test=[762.666948,722.37660334 ,679.852680692 ,608.829640431 ,527.906059957 ,461.922088383 ,346.944270107 ,229.865682586] 
exaxt_test =[769.741145127,838.1063527065705,808.2611802671888,771.6896890183064,673.2221276743697,574.8742789018773,578.6416418235431,510]

plt.title('Test error on data without outliers', fontsize = 25)

p1=plt.plot(x, capp_test,'r--^', label='c_approx')
p2=plt.plot(x, bin_test,'b-H',label='binNum_fixed')
p3=plt.plot(x, width_test,'g-<',label='width_fixed')
p4=plt.plot(x, exaxt_test,'c-8',label='exact_fixed')
p5=plt.plot(x, mllib_test,'k-D',label='MLlib_fixed')

ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),ncol=3, fancybox=True, shadow=True)

plt.xlabel('Max depth',fontsize=18)
plt.ylabel('Mean square error',fontsize=18)

plt.xticks( fontsize = 15)
plt.yticks( fontsize = 15)
# plt.axis([0,maxdepth,1000000,1080000],fontsize=48)

plt.axis(fontsize=98)


plt.legend( loc='lower left',fontsize=21 )

plt.savefig('/home/tguo/testClean.png')

# %%
# results plot
import matplotlib.pyplot as plt

# matplotlib.rcParams.update({'font.size': 52})

matplotlib.rcParams.update({'font.size': 72})

maxdepth=8
x=range(0,maxdepth)

fig = plt.figure()

plt.legend(framealpha=0.5)

plt.tick_params(labelsize= maxdepth)

capp_train=[771.08856545,764.9672098181824, 740.3939116892855, 700.9975741112505, 650.90040751234, 483.04646566080595, 178.22589175168397, 151.6327886088019]

bin_train=[771.08856545,764.324273897,739.985248741,703.871007467,649.6643822,494.899825276,178.974866547,124.008347606] 

width_train=[771.08856545, 771, 765, 723, 680,632,594,570]

mllib_train=[762.073426148,720.139181348,678.66003154,606.553416498,526.374209754,461.399140165,347.909045663,230.08420302]
exaxt_train=[771.08856545, 836.7151100286254,807.0908770251182,763.0518041779437,670.7096534920322,571.0572144974398,580.2175022679407,520.2175022679407]

plt.title('Training error on data without outliers', fontsize = 25)

p1=plt.plot(x, capp_train,'r--^', label='c_approx')
p2=plt.plot(x, bin_train,'b-H',label='binNum_fixed')
p3=plt.plot(x, width_train,'g-<',label='width_fixed')
p4=plt.plot(x, exaxt_train,'c-8',label='exact_fixed')
p5=plt.plot(x, mllib_train,'k-D',label='MLlib_fixed')

plt.xlabel('Max depth',fontsize=18)
plt.ylabel('Mean square error',fontsize=18)

plt.xticks( fontsize = 15)
plt.yticks( fontsize = 15)
# plt.axis([0,maxdepth,1000000,1080000],fontsize=48)

plt.axis(fontsize=98)


plt.legend( loc='lower left',fontsize=21 )

plt.savefig('/home/tguo/trainClean.png')

# %%
#clean data

MSE

125
[0, 0, 0, 0, 3, 6, 27, 51, 89, 109, 125]
0.0

test error at depth 1 : 722.061178985
test error at depth 2 : 677.890121689
test error at depth 3 : 604.811011388
test error at depth 4 : 526.53048095
test error at depth 5 : 463.571501548
test error at depth 6 : 348.338174181
test error at depth 7 : 228.428619434
test error at depth 8 : 107.664019556
test error at depth 9 : 10.1351299399
test error at depth 10 : 0.994190527863
[722.0611789853202, 677.8901216887728, 604.8110113875669, 526.5304809500908, 
 463.57150154818726, 348.33817418080304, 228.42861943390577, 
 107.66401955584888, 10.135129939896686, 0.9941905278626019]


TMSE

125
[0, 0, 0, 0, 3, 6, 27, 51, 89, 109, 125]
0.0

test error at depth 1 : 722.061178985
test error at depth 2 : 677.890121689
test error at depth 3 : 604.811011388
test error at depth 4 : 526.53048095
test error at depth 5 : 463.571501548
test error at depth 6 : 348.338174181
test error at depth 7 : 228.428619434
test error at depth 8 : 107.664019556
test error at depth 9 : 10.1351299399
test error at depth 10 : 0.994190527863
[722.0611789853202, 677.8901216887728, 604.8110113875669, 526.5304809500908, 
 463.57150154818726, 348.33817418080304, 228.42861943390577, 
 107.66401955584888, 10.135129939896686, 0.9941905278626019]



LAD

125
[0, 0, 0, 0, 1, 8, 30, 55, 81, 117, 125]
0.000696797803031


test error at depth 1 : 761.79028813
test error at depth 2 : 722.393324947
test error at depth 3 : 661.287266729
test error at depth 4 : 683.258022537
test error at depth 5 : 541.67488262
test error at depth 6 : 372.917664088
test error at depth 7 : 238.756088423
test error at depth 8 : 177.027557703
test error at depth 9 : 27.4961192469
test error at depth 10 : 0.9948079732
[761.7902881299493, 722.3933249466605, 661.2872667287045, 683.2580225373428, 541.6748826200677, 
 372.91766408811634, 238.7560884227464, 177.02755770295406, 27.496119246856093, 0.9948079731998074]


MAD

47
[0, 0, 0, 0, 3, 3, 25, 30, 47, 47, 47]
0.000869751033286

test error at depth 1 : 724.921560015
test error at depth 2 : 821.770475922
test error at depth 3 : 721.175298762
test error at depth 4 : 709.129252786
test error at depth 5 : 701.756470497
test error at depth 6 : 590.247978578
test error at depth 7 : 541.142995732
test error at depth 8 : 479.086032146
test error at depth 9 : 479.086032146
test error at depth 10 : 479.086032146
[724.92156001471, 821.7704759215393, 721.1752987619979, 709.1292527858527, 
 701.7564704971995, 590.2479785779877, 541.1429957320114, 479.0860321462388, 479.0860321462388, 479.0860321462388]

# %%
with outliers: outerlier percentage: 0.01

MSE

105
[0, 0, 0, 0, 1, 12, 31, 52, 70, 91, 105]
11747.4007048

test error at depth 1 : 10951.9519154
test error at depth 2 : 10874.4913409
test error at depth 3 : 10898.5890795
test error at depth 4 : 11074.68962   86
test error at depth 5 : 11027.8917796
test error at depth 6 : 11258.8055739
test error at depth 7 : 11308.4776686
test error at depth 8 : 11397.2901348
test error at depth 9 : 11471.4427182
test error at depth 10 : 11477.0047595
[10951.951915391994, 10874.491340893754, 10898.589079538771, 11074.689628642509, 
 11027.89177964135, 11258.80557388515, 11308.477668631882, 11397.29013480827, 
 11471.442718201137, 11477.004759472811]


TMSE: trimm-ratio:0.001

117
[0, 0, 0, 0, 2, 6, 31, 49, 95, 109, 117]
86.0729165188

test error at depth 1 : 722.150183177
test error at depth 2 : 678.076622725
test error at depth 3 : 626.167494271
test error at depth 4 : 529.211077976
test error at depth 5 : 459.462588026
test error at depth 6 : 365.338332024
test error at depth 7 : 272.089319399
test error at depth 8 : 193.981194561
test error at depth 9 : 118.106194274
test error at depth 10 : 105.960832383
[722.1501831772498, 678.0766227247195, 626.1674942714853, 529.2110779761191, 
 459.4625880263962, 365.3383320236384, 272.0893193991263, 193.981194561048, 
 118.10619427386612, 105.96083238309524]



LAD

125
[0, 0, 0, 0, 1, 8, 30, 55, 81, 117, 125]
0.00087839306213

test error at depth 1 : 761.866041467
test error at depth 2 : 721.819082896
test error at depth 3 : 685.477573829
test error at depth 4 : 672.802274731
test error at depth 5 : 550.63447638
test error at depth 6 : 380.088389974
test error at depth 7 : 232.571042001
test error at depth 8 : 178.360779432
test error at depth 9 : 27.3744642355
test error at depth 10 : 0.994985641852
[761.8660414673642, 721.8190828959343, 685.4775738288265, 672.8022747307433, 550.6344763795593, 
 380.08838997374625, 232.5710420009363, 178.3607794316177, 27.374464235463364, 0.9949856418517173]



MAD

63
[0, 0, 0, 0, 1, 9, 23, 35, 51, 55, 63]
0.00072720810899


test error at depth 1 : 724.66234824
test error at depth 2 : 823.350806179
test error at depth 3 : 817.638707244
test error at depth 4 : 710.780446904
test error at depth 5 : 592.913447513
test error at depth 6 : 566.120821371
test error at depth 7 : 507.235064184
test error at depth 8 : 428.118960011
test error at depth 9 : 363.740997535
test error at depth 10 : 363.585296244
[724.6623482398529, 823.3508061791998, 817.6387072436961, 710.780446904384, 
 592.9134475132386, 566.120821370631, 507.2350641839725, 428.1189600112966, 
 363.7409975347517, 363.58529624398716]

# %%
#histogram 
#without outliers 

125
[0, 0, 0, 0, 1, 8, 30, 55, 81, 117, 125]
0.000694023468362



test error at depth 1 : 762.602633688
test error at depth 2 : 722.794934554
test error at depth 3 : 661.29684505
test error at depth 4 : 683.124877913
test error at depth 5 : 541.762084958
test error at depth 6 : 372.941857353
test error at depth 7 : 238.716865725
test error at depth 8 : 177.012817898
test error at depth 9 : 27.5025911873
test error at depth 10 : 0.994790998188
[762.602633688203, 722.7949345538914, 661.2968450497801, 683.124877912768,
 541.7620849580161, 372.9418573532756, 238.7168657251205, 177.0128178978956, 
 27.502591187332897, 0.9947909981879723]



#with outliers

125
[0, 0, 0, 0, 1, 8, 30, 55, 81, 117, 125]
0.000864066861598

test error at depth 1 : 763.092715869
test error at depth 2 : 721.712953581
test error at depth 3 : 685.503661429
test error at depth 4 : 672.868800287
test error at depth 5 : 550.558968619
test error at depth 6 : 380.129039584
test error at depth 7 : 232.56670388
test error at depth 8 : 178.306420224
test error at depth 9 : 27.377739921
test error at depth 10 : 0.994966814179
[763.0927158694144, 721.7129535806937, 685.503661428629, 672.8688002869735, 
 550.5589686194592, 380.12903958362125, 232.56670387967736, 178.30642022445798, 
 27.37773992104267, 0.9949668141791402]






125
[0, 0, 0, 0, 0, 11, 29, 49, 91, 113, 125]
0.00666934082414

test error at depth 1 : 816.71773784
test error at depth 2 : 801.794760631
test error at depth 3 : 733.121444618
test error at depth 4 : 658.481651862
test error at depth 5 : 579.405747502
test error at depth 6 : 473.265121138
test error at depth 7 : 390.226110977
test error at depth 8 : 154.23194535
test error at depth 9 : 3.06869152771
test error at depth 10 : 1.01435910391
[816.7177378397466, 801.7947606312379, 733.1214446178271, 658.4816518623684, 
 579.4057475023022, 473.2651211377025, 390.22611097697114, 154.231945349924, 
 3.068691527708261, 1.014359103907498]



synthetic_data_6zeros_0.01percen.txt'

125
[0, 0, 0, 0, 0, 0, 27, 81, 117, 125, 125]
0.00111887904262

test error at depth 1 : 749.018570669
test error at depth 2 : 707.890945579
test error at depth 3 : 686.704982306
test error at depth 4 : 475.914064373
test error at depth 5 : 448.421455377
test error at depth 6 : 348.751694961
test error at depth 7 : 101.713436048
test error at depth 8 : 77.1355784508
test error at depth 9 : 1.00065966373
test error at depth 10 : 1.00065966373
[749.018570668834, 707.89094557874, 686.7049823063767, 475.91406437323826, 
 448.42145537709, 348.7516949605679, 101.71343604750619, 77.13557845078279, 
 1.0006596637335925, 1.0006596637335925]


runing time :[[230.2208399772644]]
    

    
data_6zeros_0.01percen,   899443,  

[[5277.208759069443]]


dataset: 300000
1 1
time consumption ratio 8 : 575.421093941 5.11430311203
2 2
time consumption ratio 8 : 913.029434919 26.2319910526
4 4
time consumption ratio 8 : 1191.51632905 50.1613161564
8 8
time consumption ratio 8 : 1062.89347696 85.9076850414
16 16
time consumption ratio 8 : 659.388391972 61.6955149174
32 32
time consumption ratio 8 : 400.757678032 91.3947350979
64 64
time consumption ratio 8 : 300.690107107 129.179865837
128 128
time consumption ratio 8 : 194.101601839 154.481981039
error at tree height 8 : 0 0
running time at tree height 8 : 5902.10194612 5747.59958005
number of leaf nodes at tree height 8 : 256
    

dataset: 400379, 4f5v, 
outliers: 1p 6zeros 
1 1
time consumption ratio 10 : 254.177439928 1.31516313553
2 2
time consumption ratio 10 : 250.973127127 2.19380688667
4 4
time consumption ratio 10 : 254.026736975 2.85820102692
8 8
time consumption ratio 10 : 249.102877855 3.84276604652
16 16
time consumption ratio 10 : 240.719442129 4.69074988365
32 32
time consumption ratio 10 : 227.134561062 4.40084290504
64 64
time consumption ratio 10 : 203.316897154 5.29616785049
128 128
time consumption ratio 10 : 166.820469141 5.89417600632
256 256
time consumption ratio 10 : 119.416610003 4.91371417046
512 512
time consumption ratio 10 : 72.893226862 3.64439797401
error at tree height 10 : 0 0
running time at tree height 10 : 2077.67835999 2074.02918005
number of leaf nodes at tree height 10 : 1024
    
dataset: 400379, 20f10v,   
test error at depth 1 : 847.009405587
test error at depth 2 : 841.687493095
test error at depth 3 : 830.245056119
test error at depth 4 : 827.491221829
test error at depth 5 : 822.463562978
test error at depth 6 : 772.220903018
test error at depth 7 : 674.491556443
test error at depth 8 : 472.660847156
test error at depth 9 : 289.663224571
test error at depth 10 : 90.3379685404
[847.0094055873612, 841.6874930949978, 830.2450561188137, 827.491221828987,
 822.4635629781191, 772.2209030178125, 674.4915564433072, 472.66084715564307, 
 289.66322457095856, 90.33796854037784]

[2077.6783599853516]
